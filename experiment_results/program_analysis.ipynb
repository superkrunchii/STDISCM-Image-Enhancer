# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
case1 = pd.read_excel('./results.xlsx', sheet_name="Case1")
case2 = pd.read_excel('./results.xlsx', sheet_name='Case2')

# %%
sns.lineplot(data=case1, x='No. of Threads',y='Avg. Enhanced Image (per min.)',
    markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='No. of Threads', ylabel='Avg. Enhanced Image (per min.)'>

# %%
sns.lineplot(data=case2, x='No. of Threads',y='Avg. Enhanced Image (per min.)',
    markers=True, dashes=False)
# Out:
# <AxesSubplot:xlabel='No. of Threads', ylabel='Avg. Enhanced Image (per min.)'>
